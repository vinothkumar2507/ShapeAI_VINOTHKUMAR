# %%
from keras.datasets import mnist

data = mnist.load_data()

Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz 11493376/11498434 [=

===========] - 0s @us/step

(X_train, y_train), (X_test, y_test)) = data

X_train = X train. reshape((X_train.shape [0], 28*28)).astype('float32') X_test = Xtest.reshape( (X_test. shape [0], 28*28)).astype('float32')

X_train = X_train / 255 X_test = X_test / 255

from keras.utils import np_utils

print(y_test.shape)

y train = np_utils.to_categorical(y_train) y_test = np_utils.to_categorical(y_test)

num_classes = y_test.shape [1] print(y_test.shape)

(10000,)

(10000, 10)
model Sequential()

model.add(Denset 32, input din 28-28,

model.add(Densel64,

activations relu'))

activations rel}}

model.add(Dense(10, activations softmax))

model.compile(loss='categorical_crossentropy",

model.summary()

Model: "sequential"

Layer (type)

dense (Dense)

optimizer='adan',

metrics=

Output Shape

(None, 32)

None

641

Param #

25120

2112
model.fiti trah, y train, epochs 10, batch size=1001

Epoch 1/18

Epock 2/18

Epoch 3/18

2s 2ns/step-loss: 0.7690-accuracy: 8.7718

- 1s 2s/step loss: 8.2095- accuracy: 8.9483

2s 3ns/step-loss: 0.1626-accuracy: 0.9519

- 1s 2s/step-loss: 0.1374- accuracy: 0.9600

2s 2ns/step-loss: 0.1138-accuracy

Epoch 5/10
600/600 1:

Epoch 5/10

600/600 [=

Epoch 6/10

600/600 [

Epoch 7/10

600/600 [

Epoch 8/10

600/600 I

Epoch 9/10

600/600 [

Epoch 10/10

600/600 --------

1s 2ms/step - Loss: 0.1374- accuracy: 0.9600

- 1s 2ms/step-loss: 0.1138 - accuracy: 0.9659

- 1s 2ms/step - loss: 0.1016- accuracy: 0.9686

- 1s 2ms/step - loss: 0.0878- accuracy: 0.9738

- 1s 2ms/step loss: 0.0742- accuracy: 0.9779

-------------] 1s 2ms/step loss: 0.0719-accuracy: 0.9781

------------] 1s 2ms/step loss:

<tensorflow.python.keras.callbacks.History at 0x7fa231be4790>

scores model.evaluate(X_test, y test) print(scores)

10.1023077666759491, 0.9688888882969666]

0.0656 - accuracy: 0.9799

1ms/step-loss:

0.1823-

accuracy:

0.9688
notes_20210518164726.txt
Displaying notes_20210518164726.txt.
# Out:
#   File "<ipython-input-1-20e45868b6aa>", line 5
# ...
#                    ^
# SyntaxError: invalid syntax
